# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
data = pd.read_csv('/content/top_selling_mobile_phones.csv')
data.head(5)
# Out:
#   Manufacturer                         Model  Form factor Smartphone?  Year  \
# 0        Nokia                          1100          Bar          No  2003
# 1        Nokia                          1110          Bar          No  2005
# 2        Apple    iPhone 6 and iPhone 6 Plus  Touchscreen         Yes  2014
# 3        Nokia                   105 series,          Bar          No  2013
# 4        Apple  iPhone 6S and iPhone 6S Plus  Touchscreen         Yes  2015
#
#   Graph (million units)  Graph (million units).1
# 0          250[4][1][5]                      NaN
# 1        247.5[4][1][6]                      NaN
# 2              222.4[7]                      NaN
# 3                200[8]                      NaN
# 4  174.1[9][10][11][12]                      NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Manufacturer             115 non-null    object
#  1   Model                    115 non-null    object
#  2   Form factor              115 non-null    object
#  3   Smartphone?              115 non-null    object
#  4   Year                     115 non-null    int64
#  5   Graph (million units)    115 non-null    object
#  6   Graph (million units).1  0 non-null      float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 6.4+ KB

# %%
df=data.drop('Graph (million units).1',axis=1)

# %%
df
# Out:
#     Manufacturer                         Model   Form factor Smartphone?  \
# 0          Nokia                          1100           Bar          No
# 1          Nokia                          1110           Bar          No
# 2          Apple    iPhone 6 and iPhone 6 Plus   Touchscreen         Yes
# 3          Nokia                   105 series,           Bar          No
# 4          Apple  iPhone 6S and iPhone 6S Plus   Touchscreen         Yes
# ..           ...                           ...           ...         ...
# 110           LG                            G2   Touchscreen         Yes
# 111         LeTV                   LeEco Le 1s   Touchscreen         Yes
# 112       Google            Pixel and Pixel XL   Touchscreen         Yes
# 113         Palm                        Centro  Keyboard bar         Yes
# 114        Nokia                           N97   Tilt slider         Yes
#
#      Year Graph (million units)
# 0    2003          250[4][1][5]
# ...

# %%
sns.histplot(df['Year'], bins=20, kde=True)
plt.title('Year')
plt.xlabel(' Smartphone (%)')
plt.show()

# %%
plt.hist(df['Year'])
# Out:
# (array([ 1.,  2.,  7., 17., 12., 14., 12.,  9., 31., 10.]),
#  array([1996. , 1998.6, 2001.2, 2003.8, 2006.4, 2009. , 2011.6, 2014.2,
#         2016.8, 2019.4, 2022. ]),
#  <BarContainer object of 10 artists>)

# %%
ax = df['Manufacturer'].value_counts().head(10).plot(kind= 'bar',title='Name of the Manufacturer')
ax.set_xlabel('Manufacturer')
ax.set_ylabel('Name of the Manufacturer ')
# Out:
# Text(0, 0.5, 'Name of the Manufacturer ')

# %%
df['Form factor'].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(df['Year'])
# Out:
# <Axes: ylabel='Year'>

# %%
df.describe()
# Out:
#               Year
# count   115.000000
# mean   2012.165217
# std       6.246305
# min    1996.000000
# 25%    2007.000000
# 50%    2013.000000
# 75%    2018.000000
# max    2022.000000

# %%
sns.countplot(x=df['Form factor'])
# Out:
# <Axes: xlabel='Form factor', ylabel='count'>

# %%
sns.boxplot(x='Year', y='Manufacturer', data=df)
plt.title('Manufacturing year of the phone')
plt.xlabel('Year')
plt.ylabel( 'Manufacturer %')
plt.show()

# %%
sns.heatmap(df.isnull())
sns.heatmap(flight.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# <Axes: >
